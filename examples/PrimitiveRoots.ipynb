# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys, os
sys.path.insert(0, os.path.abspath("../"))
from cnlecture import functions as fc

# %%
# plot primitive roots with arg < pi.
# Note: complex conjugates of primitive roots are also primitive.
fc.primitive_roots(7)
plt.gcf().set_dpi(150)
#plt.savefig("../../primitive_roots.pdf",bbox_inches='tight')
