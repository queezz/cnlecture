# %%
# %matplotlib widget

# %%
import sys, os
sys.path.insert(0, os.path.abspath("../"))
from cnlecture import functions as fc

# %%
fc.modular_surface(power=2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
